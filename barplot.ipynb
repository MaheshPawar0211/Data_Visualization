# %%
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd

# %% [markdown]
# ## Most important method is
# * fig,ax = plt.subplots(1, 1, figsize=(10,7))
# * ax.set_yticks(y_pos)   =>  this is list number where we need to plot bar usually its formed by np.arange(len(bars))
# * ax.set_yticklabels(bars) => this is list name which we want to give to bar

# %% [markdown]
# ## Basic Barplot

# %% [markdown]
# ### WIth plt method

# %%
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = np.arange(len(bars))
# Create bars
plt.bar(y_pos, height)
# Create names on the x-axis
plt.xticks(y_pos, bars)
# Show graphic
plt.show()

# %% [markdown]
# ### with axes method

# %%
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = np.arange(len(bars))
# Create bars
fig,ax = plt.subplots(1, 1, figsize=(14, 6))
ax.bar(y_pos, height)
# Create names on the x-axis
ax.set_xticks(y_pos)
ax.set_xticklabels(bars, rotation=65)
# Show graphic
plt.show()

# %% [markdown]
# ## Horizontal barplot

# %% [markdown]
# ### with plt method

# %%
# Make fake dataset
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = np.arange(len(bars))
# Create horizontal bars
plt.barh(y_pos, height)
# Create names on the y-axis
plt.yticks(y_pos, bars)
# Show graphic
plt.show()

# %% [markdown]
# ### with axes method

# %%
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = np.arange(len(bars))
# Create bars
fig,ax = plt.subplots(1, 1, figsize=(10,7))
ax.barh(y_pos, height)
# Create names on the x-axis
ax.set_yticks(y_pos)
ax.set_yticklabels(bars, rotation=0)
# Show graphic
plt.show()

# %% [markdown]
# ## Control color of barplots

# %% [markdown]
# ### with plt method

# %%
# Make a fake dataset
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = np.arange(len(bars))
plt.bar(y_pos, height, color=(0.2, 0.4, 0.6, 0.6))
plt.xticks(y_pos, bars)
plt.title('Uniform color using RGB')
plt.xlabel('categories')
plt.ylabel('values')
plt.show()

plt.bar(y_pos, height, color=['black', 'red', 'green', 'blue', 'cyan'])
plt.xticks(y_pos, bars)
plt.title('Different color for each bar')
plt.xlabel('categories')
plt.ylabel('values')
plt.show()

plt.bar(y_pos, height, color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(y_pos, bars)
plt.title('Control color of border')
plt.xlabel('categories')
plt.ylabel('values')
plt.show()

# %% [markdown]
# ### with axes method

# %%
# Make a fake dataset
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = np.arange(len(bars))
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 16))
ax1.bar(y_pos, height, color=(0.2, 0.4, 0.6, 0.6))
ax1.set_xticks(y_pos)
ax1.set_xticklabels(bars)
ax1.set_title('Uniform color using RGB')
ax1.set_xlabel('categories')
ax1.set_ylabel('values')

ax2.bar(y_pos, height, color=['black', 'red', 'green', 'blue', 'cyan'])
ax2.set_xticks(y_pos)
ax2.set_xticklabels(bars)
ax2.set_title('Different color for each bar')
ax2.set_xlabel('categories')
ax2.set_ylabel('values')

ax3.bar(y_pos, height, color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
ax3.set_xticks(y_pos)
ax3.set_xticklabels(bars)
ax3.set_title('Control color of border')
ax3.set_xlabel('categories')
ax3.set_ylabel('values')
plt.show()

# %% [markdown]
# ## Control width and space in barplots

# %% [markdown]
# ### with plt method

# %%
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
# Choose the position of each barplots on the x-axis (space=1,4,3,1)
y_pos = [0,1,5,8,9]
# Create bars
plt.bar(y_pos, height)
# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.show()
# Make fake dataset
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
# Choose the width of each bar and their positions
width = [0.1,0.2,3,1.5,0.3]
y_pos = [0,0.3,2,4.5,5.5]
# Make the plot
plt.bar(y_pos, height, width=width)
plt.xticks(y_pos, bars)
plt.show()

# %% [markdown]
# ### with axes method

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = [0,1,5,8,9]
ax1.bar(y_pos, height)
ax1.set_xticks(y_pos)
ax1.set_xticklabels(bars)

ax1.set_title('Control Space')
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
width = [0.1,0.2,3,1.5,0.3]
y_pos = [0,0.3,2,4.5,5.5] 
ax2.bar(y_pos, height, width=width)
ax2.set_xticks(y_pos)
ax2.set_xticklabels(bars)
ax2.set_title('Control Width')
plt.show()

# %% [markdown]
# ## Custom barplot layout

# %% [markdown]
# ### with plt method

# %%
height = [3, 12, 5, 18, 45]
# Choose the names of the bars
bars = ('group1', 'group2', 'group3', 'group4', 'group5')
y_pos = np.arange(len(bars))
# Create bars
plt.bar(y_pos, height)
# Create names on the x-axis
plt.xticks(y_pos, bars, color='orange')
plt.yticks(color='orange')
# Show graphic
plt.title('Custom axis name')
plt.show()

height = [3, 12, 5, 18, 45]
bars = ("very long group name 1","very long group name 2","very long group name 3","very long group name 4","very long group name 5")
# Create bars
plt.bar(y_pos, height)
# Rotation of the bars names
plt.xticks(y_pos, bars, rotation=90)
# Custom the subplot layout
plt.subplots_adjust(bottom=0.4, top=0.99)
# Show graphic
plt.title('Increase bottom margin')
plt.show()

# %% [markdown]
# ### with axes method

# %%
f, (ax1, ax2) = plt.subplots(2,1, figsize=(8,12))
height = [3, 12, 5, 18, 45]
bars = ('group1', 'group2', 'group3', 'group4', 'group5')
y_pos = np.arange(len(bars))
ax1.bar(y_pos, height)
ax1.set_xticks(y_pos)
ax1.set_xticklabels(bars)
ax1.tick_params(colors='orange')
#ax1.set_yticklabels(height,color='orange')
ax1.set_title('Custom axis name')

height = [3, 12, 5, 18, 45]
bars = ("very long group name 1","very long group name 2","very long group name 3","very long group name 4","very long group name 5")
# Create bars
ax2.bar(y_pos, height)
ax2.set_xticks(y_pos)
ax2.set_xticklabels(bars,rotation=90)
ax2.set_title('Increase bottom margin')
plt.show()

# %% [markdown]
# ## Grouped barplot

# %% [markdown]
# ### Using plt method

# %%
# set width of bar
barWidth = 0.25
# set height of bar
bars1 = [12, 30, 1, 8, 22]
bars2 = [28, 6, 16, 5, 10]
bars3 = [29, 3, 24, 25, 17]
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='var2')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B', 'C', 'D', 'E'])
# Create legend & Show graphic
plt.legend()
plt.show()

# %% [markdown]
# ### Using axes method

# %%
# set width of bar
barWidth = 0.25
# set height of bar
fig,ax = plt.subplots(1, 1, figsize=(10,7))
bars1 = [12, 30, 1, 8, 22]
bars2 = [28, 6, 16, 5, 10]
bars3 = [29, 3, 24, 25, 17]
bar_label=('A', 'B', 'C', 'D', 'E')
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
# Make the plot
ax.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
ax.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='var2')
ax.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
# Add xticks on the middle of the group bars
ax.set_xlabel('group', fontweight='bold')
ax.set_xticks([r + barWidth for r in range(len(bars1))])
ax.set_xticklabels(bar_label)
# Create legend & Show graphic
ax.legend()
plt.show()

# %% [markdown]
# ## Stacked barplot with matplotlib

# %% [markdown]
# ### Using plt method

# %%
from matplotlib import rc
# y-axis in bold
rc('font', weight='bold')
# Values of each group
bars1 = [12, 28, 1, 8, 22]
bars2 = [28, 7, 16, 4, 10]
bars3 = [25, 3, 23, 25, 17]
# Heights of bars1 + bars2
bars = np.add(bars1, bars2).tolist()
# The position of the bars on the x-axis
r = [0,1,2,3,4]
# Names of group and bar width
names = ['A','B','C','D','E']
barWidth = 1
# Create brown bars
plt.bar(r, bars1, color='#7f6d5f', edgecolor='white', width=barWidth)
# Create green bars (middle), on top of the firs ones
plt.bar(r, bars2, bottom=bars1, color='#557f2d', edgecolor='white', width=barWidth)
# Create green bars (top)
plt.bar(r, bars3, bottom=bars, color='#2d7f5e', edgecolor='white', width=barWidth)
# Custom X axis
plt.xticks(r, names, fontweight='bold')
plt.xlabel("group")
# Show graphic
plt.show()

# %% [markdown]
# ### Using axes method

# %%
from matplotlib import rc
# y-axis in bold
rc('font', weight='bold')
fig,ax = plt.subplots(1, 1, figsize=(10,7))
# Values of each group
bars1 = [12, 28, 1, 8, 22]
bars2 = [28, 7, 16, 4, 10]
bars3 = [25, 3, 23, 25, 17]
# Heights of bars1 + bars2
bars = np.add(bars1, bars2).tolist()
# The position of the bars on the x-axis
r = [0,1,2,3,4]
# Names of group and bar width
names = ['A','B','C','D','E']
barWidth = 1
# Create brown bars
ax.bar(r, bars1, color='#7f6d5f', edgecolor='white', width=barWidth)
# Create green bars (middle), on top of the firs ones
ax.bar(r, bars2, bottom=bars1, color='#557f2d', edgecolor='white', width=barWidth)
# Create green bars (top)
ax.bar(r, bars3, bottom=bars, color='#2d7f5e', edgecolor='white', width=barWidth)
# Custom X axis
ax.set_xticks(r)
ax.set_xticklabels(names,fontweight='bold')
ax.set_xlabel("group")
# Show graphic
plt.show()

# %% [markdown]
# ## Percent stacked barplot

# %% [markdown]
# ### Using plt method

# %%
# Data
r = [0,1,2,3,4]
raw_data = {'greenBars': [20, 1.5, 7, 10, 5], 'orangeBars': [5, 15, 5, 10, 15],'blueBars': [2, 15, 18, 5, 10]}
df = pd.DataFrame(raw_data)
# From raw value to percentage
totals = [i+j+k for i,j,k in zip(df['greenBars'], df['orangeBars'], df['blueBars'])]
greenBars = [i / j * 100 for i,j in zip(df['greenBars'], totals)]
orangeBars = [i / j * 100 for i,j in zip(df['orangeBars'], totals)]
blueBars = [i / j * 100 for i,j in zip(df['blueBars'], totals)]
# plot
barWidth = 0.85
names = ('A','B','C','D','E')
# Create green Bars
plt.bar(r, greenBars, color='#b5ffb9', edgecolor='white', width=barWidth, label="group A")
# Create orange Bars
plt.bar(r, orangeBars, bottom=greenBars, color='#f9bc86', edgecolor='white', width=barWidth, label="group B")
# Create blue Bars
plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth, label="group C")
 
# Custom x axis
plt.xticks(r, names)
plt.xlabel("group")
 
# Add a legend
plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
 
# Show graphic
plt.show()

# %% [markdown]
# ### Using axes method

# %%
# Data
r = [0,1,2,3,4]
fig,ax = plt.subplots(1, 1, figsize=(10,7))
raw_data = {'greenBars': [20, 1.5, 7, 10, 5], 'orangeBars': [5, 15, 5, 10, 15],'blueBars': [2, 15, 18, 5, 10]}
df = pd.DataFrame(raw_data)
# From raw value to percentage
totals = [i+j+k for i,j,k in zip(df['greenBars'], df['orangeBars'], df['blueBars'])]
greenBars = [i / j * 100 for i,j in zip(df['greenBars'], totals)]
orangeBars = [i / j * 100 for i,j in zip(df['orangeBars'], totals)]
blueBars = [i / j * 100 for i,j in zip(df['blueBars'], totals)]
# plot
barWidth = 0.85
names = ('A','B','C','D','E')
# Create green Bars
ax.bar(r, greenBars, color='#b5ffb9', edgecolor='white', width=barWidth, label="group A")
# Create orange Bars
ax.bar(r, orangeBars, bottom=greenBars, color='#f9bc86', edgecolor='white', width=barWidth, label="group B")
# Create blue Bars
ax.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth, label="group C")
 
# Custom x axis
ax.set_xticks(r)
ax.set_xticklabels(names)
ax.set_xlabel("group")
 
# Add a legend
ax.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
 
# Show graphic
plt.show()

# %% [markdown]
# ## Barplot with number of observation

# %% [markdown]
# ### Using plt method

# %%
# library
import matplotlib.pyplot as plt
 
# Create bars
barWidth = 0.9
bars1 = [3, 3, 1]
bars2 = [4, 2, 3]
bars3 = [4, 6, 7, 10, 4, 4]
bars4 = bars1 + bars2 + bars3
 
# The X position of bars
r1 = [1,5,9]
r2 = [2,6,10]
r3 = [3,4,7,8,11,12]
r4 = r1 + r2 + r3
 
# Create barplot
plt.bar(r1, bars1, width = barWidth, color = (0.3,0.1,0.4,0.6), label='Alone')
plt.bar(r2, bars2, width = barWidth, color = (0.3,0.5,0.4,0.6), label='With Himself')
plt.bar(r3, bars3, width = barWidth, color = (0.3,0.9,0.4,0.6), label='With other genotype')
# Note: the barplot could be created easily. See the barplot section for other examples.
 
# Create legend
plt.legend()
 
# Text below each barplot with a rotation at 90°
plt.xticks([r + barWidth for r in range(len(r4))], ['DD', 'with himself', 'with DC', 'with Silur', 'DC', 'with himself', 'with DD', 'with Silur', 'Silur', 'with himself', 'with DD', 'with DC'], rotation=90)
 
# Create labels
label = ['n = 6', 'n = 25', 'n = 13', 'n = 36', 'n = 30', 'n = 11', 'n = 16', 'n = 37', 'n = 14', 'n = 4', 'n = 31', 'n = 34']
 
# Text on the top of each barplot
# ***************How to put number values to each bar plot

for i in range(len(r4)):
    plt.text(x = r4[i]-0.5 , y = bars4[i]+0.1, s = label[i], size = 7)
 
# Adjust the margins
plt.subplots_adjust(bottom= 0.2, top = 0.98)
 
# Show graphic
plt.show()
